# %% [markdown]
# NAME : SWETHA V

# %% [markdown]
# REGISTER NUMBER : 20MIS0405

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
#2. 
data = pd.read_csv('Housing.csv')

# %%
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
#3.Univariate anaysis
sns.distplot(data['stories'])
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_17864\3685121388.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(data['stories'])
# <Axes: xlabel='stories', ylabel='Density'>

# %%
#bar plot

sns.countplot(x='stories', data=data)
plt.xlabel('stories')
plt.ylabel('Count')
plt.title('Stories')
plt.show()

# %%
# bivariate analysis
#line plot 
plt.plot(data['stories'], data['parking'])
plt.xlabel('stories')
plt.ylabel('Stories')
plt.title('Parking')
plt.show()

# %%
#scatter plot
plt.scatter(data['stories'], data['parking'])
plt.xlabel('Stories')
plt.ylabel('Parking')
plt.title('Scatter Plot')
plt.show()

# %%
#multivariate analysis

plt.figure(figsize=(10,6))

plt.subplot(2,2,1)
plt.plot(data['stories'],data['parking'])

plt.subplot(2,2,2)
plt.plot(data['stories'],data['parking'])

plt.subplot(2,2,3)
plt.plot(data['stories'],data['furnishingstatus'])

plt.subplot(2,2,4)
plt.plot(data['stories'],data['furnishingstatus'])

# %%
variables = ['stories','parking']

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 545 entries, 0 to 544
# Data columns (total 12 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   price             545 non-null    int64
#  1   area              545 non-null    int64
#  2   bedrooms          545 non-null    int64
#  3   bathrooms         545 non-null    int64
#  4   stories           545 non-null    int64
#  5   mainroad          545 non-null    object
#  6   guestroom         545 non-null    object
#  7   basement          545 non-null    object
#  8   hotwaterheating   545 non-null    object
#  9   airconditioning   545 non-null    object
#  10  parking           545 non-null    int64
#  11  furnishingstatus  545 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 51.2+ KB

# %%
#4.descriptive analysis on the dataset
data.describe()
# Out:
#               price          area    bedrooms   bathrooms     stories  \
# count  5.450000e+02    545.000000  545.000000  545.000000  545.000000
# mean   4.766729e+06   5150.541284    2.965138    1.286239    1.805505
# std    1.870440e+06   2170.141023    0.738064    0.502470    0.867492
# min    1.750000e+06   1650.000000    1.000000    1.000000    1.000000
# 25%    3.430000e+06   3600.000000    2.000000    1.000000    1.000000
# 50%    4.340000e+06   4600.000000    3.000000    1.000000    2.000000
# 75%    5.740000e+06   6360.000000    3.000000    2.000000    2.000000
# max    1.330000e+07  16200.000000    6.000000    4.000000    4.000000
#
#           parking
# count  545.000000
# mean     0.693578
# std      0.861586
# min      0.000000
# 25%      0.000000
# 50%      0.000000
# 75%      1.000000
# max      3.000000

# %%
data.mode()
# Out:
#      price    area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  3500000  6000.0       3.0        1.0      2.0      yes        no       no
# 1  4200000     NaN       NaN        NaN      NaN      NaN       NaN      NaN
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no              no      0.0   semi-furnished
# 1             NaN             NaN      NaN              NaN

# %%
#5. check formissing values
data.isna()
# Out:
#      price   area  bedrooms  bathrooms  stories  mainroad  guestroom  \
# 0    False  False     False      False    False     False      False
# 1    False  False     False      False    False     False      False
# 2    False  False     False      False    False     False      False
# 3    False  False     False      False    False     False      False
# 4    False  False     False      False    False     False      False
# ..     ...    ...       ...        ...      ...       ...        ...
# 540  False  False     False      False    False     False      False
# 541  False  False     False      False    False     False      False
# 542  False  False     False      False    False     False      False
# 543  False  False     False      False    False     False      False
# 544  False  False     False      False    False     False      False
#
#      basement  hotwaterheating  airconditioning  parking  furnishingstatus
# ...

# %%
data.isnull().any()
# Out:
# price               False
# area                False
# bedrooms            False
# bathrooms           False
# stories             False
# mainroad            False
# guestroom           False
# basement            False
# hotwaterheating     False
# airconditioning     False
# parking             False
# furnishingstatus    False
# dtype: bool

# %%
data.isnull().sum()
# Out:
# price               0
# area                0
# bedrooms            0
# bathrooms           0
# stories             0
# mainroad            0
# guestroom           0
# basement            0
# hotwaterheating     0
# airconditioning     0
# parking             0
# furnishingstatus    0
# dtype: int64

# %%
#6. outlier
sns.boxplot(data.stories)
# Out:
# <Axes: >

# %%
perc99=data.stories.quantile(0.99)
perc99
# Out:
# 4.0

# %%
data=data[data.stories<=perc99]
sns.boxplot(data.stories)
data
# Out:
#         price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0    13300000  7420         4          2        3      yes        no       no
# 1    12250000  8960         4          4        4      yes        no       no
# 2    12250000  9960         3          2        2      yes        no      yes
# 3    12215000  7500         4          2        2      yes        no      yes
# 4    11410000  7420         4          1        2      yes       yes      yes
# ..        ...   ...       ...        ...      ...      ...       ...      ...
# 540   1820000  3000         2          1        1      yes        no      yes
# 541   1767150  2400         3          1        1       no        no       no
# 542   1750000  3620         2          1        1      yes        no       no
# 543   1750000  2910         3          1        1       no        no       no
# 544   1750000  3850         3          1        2      yes        no       no
#
# ...

# %%
quantile = data.quantile(q=[0.75,0.25])
quantile
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_17864\1929517990.py:1: FutureWarning: The default value of numeric_only in DataFrame.quantile is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   quantile = data.quantile(q=[0.75,0.25])
#           price    area  bedrooms  bathrooms  stories  parking
# 0.75  5740000.0  6360.0       3.0        2.0      2.0      1.0
# 0.25  3430000.0  3600.0       2.0        1.0      1.0      0.0

# %%
quantile.iloc[0]
# Out:
# price        5740000.0
# area            6360.0
# bedrooms           3.0
# bathrooms          2.0
# stories            2.0
# parking            1.0
# Name: 0.75, dtype: float64

# %%
quantile.iloc[1]
# Out:
# price        3430000.0
# area            3600.0
# bedrooms           2.0
# bathrooms          1.0
# stories            1.0
# parking            0.0
# Name: 0.25, dtype: float64

# %%
IQR = quantile.iloc[0]-quantile.iloc[1]
IQR
# Out:
# price        2310000.0
# area            2760.0
# bedrooms           1.0
# bathrooms          1.0
# stories            1.0
# parking            1.0
# dtype: float64

# %%
upper_extreme = quantile.iloc[0]+(1.58*IQR)
upper_extreme
# Out:
# price        9389800.00
# area           10720.80
# bedrooms           4.58
# bathrooms          3.58
# stories            3.58
# parking            2.58
# dtype: float64

# %%
lower_extreme = quantile.iloc[1]-(1.5*IQR)
lower_extreme
# Out:
# price       -35000.0
# area          -540.0
# bedrooms         0.5
# bathrooms       -0.5
# stories         -0.5
# parking         -1.5
# dtype: float64

# %%
# 7. check for categorical columns and perform encoding
data.columns
# Out:
# Index(['price', 'area', 'bedrooms', 'bathrooms', 'stories', 'mainroad',
#        'guestroom', 'basement', 'hotwaterheating', 'airconditioning',
#        'parking', 'furnishingstatus'],
#       dtype='object')

# %%
#label encoding
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
data.stories = le.fit_transform(data.stories)

# %%
data.parking = le.fit_transform(data.parking)

# %%
data.head()
# Out:
#       price  area  bedrooms  bathrooms  stories mainroad guestroom basement  \
# 0  13300000  7420         4          2        2      yes        no       no
# 1  12250000  8960         4          4        3      yes        no       no
# 2  12250000  9960         3          2        1      yes        no      yes
# 3  12215000  7500         4          2        1      yes        no      yes
# 4  11410000  7420         4          1        1      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus
# 0              no             yes        2        furnished
# 1              no             yes        3        furnished
# 2              no              no        2   semi-furnished
# 3              no             yes        3        furnished
# 4              no             yes        2        furnished

# %%
#one hot encoding
data_main = pd.get_dummies(data,columns=['stories'])

# %%
data_main.head()
# Out:
#       price  area  bedrooms  bathrooms mainroad guestroom basement  \
# 0  13300000  7420         4          2      yes        no       no
# 1  12250000  8960         4          4      yes        no       no
# 2  12250000  9960         3          2      yes        no      yes
# 3  12215000  7500         4          2      yes        no      yes
# 4  11410000  7420         4          1      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus  stories_0  \
# 0              no             yes        2        furnished          0
# 1              no             yes        3        furnished          0
# 2              no              no        2   semi-furnished          0
# 3              no             yes        3        furnished          0
# 4              no             yes        2        furnished          0
#
#    stories_1  stories_2  stories_3
# 0          0          1          0
# 1          0          0          1
# ...

# %%
data_main.corr()
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_17864\1750094720.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data_main.corr()
#               price      area  bedrooms  bathrooms   parking  stories_0  \
# price      1.000000  0.535997  0.366494   0.517545  0.384394  -0.269496
# area       0.535997  1.000000  0.151858   0.193820  0.352980   0.054276
# bedrooms   0.366494  0.151858  1.000000   0.373930  0.139270  -0.510235
# bathrooms  0.517545  0.193820  0.373930   1.000000  0.177496  -0.251905
# parking    0.384394  0.352980  0.139270   0.177496  1.000000   0.015383
# stories_0 -0.269496  0.054276 -0.510235  -0.251905  0.015383   1.000000
# stories_1 -0.001251 -0.159838  0.377769   0.080144 -0.043285  -0.743907
# stories_2  0.136486  0.021268  0.100010   0.040225 -0.074838  -0.234561
# ...

# %%
data_main=pd.get_dummies(data,columns=['stories'])

# %%
data_main.head()
# Out:
#       price  area  bedrooms  bathrooms mainroad guestroom basement  \
# 0  13300000  7420         4          2      yes        no       no
# 1  12250000  8960         4          4      yes        no       no
# 2  12250000  9960         3          2      yes        no      yes
# 3  12215000  7500         4          2      yes        no      yes
# 4  11410000  7420         4          1      yes       yes      yes
#
#   hotwaterheating airconditioning  parking furnishingstatus  stories_0  \
# 0              no             yes        2        furnished          0
# 1              no             yes        3        furnished          0
# 2              no              no        2   semi-furnished          0
# 3              no             yes        3        furnished          0
# 4              no             yes        2        furnished          0
#
#    stories_1  stories_2  stories_3
# 0          0          1          0
# 1          0          0          1
# ...

# %%
plt.figure(figsize=(10,8))
sns.heatmap(data_main.corr(),annot=True)
# Out:
# C:\Users\lenovo\AppData\Local\Temp\ipykernel_17864\4162214101.py:2: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(data_main.corr(),annot=True)
# <Axes: >

# %%
#8. split the data into dependent and independent variables

dependent_variable = 'stories'

# Separate the dependent variable from the independent variables
X = data.drop(dependent_variable, axis=1)  # Independent variables
y = data[dependent_variable]  # Dependent variable

# %%
X
# Out:
#         price  area  bedrooms  bathrooms mainroad guestroom basement  \
# 0    13300000  7420         4          2      yes        no       no
# 1    12250000  8960         4          4      yes        no       no
# 2    12250000  9960         3          2      yes        no      yes
# 3    12215000  7500         4          2      yes        no      yes
# 4    11410000  7420         4          1      yes       yes      yes
# ..        ...   ...       ...        ...      ...       ...      ...
# 540   1820000  3000         2          1      yes        no      yes
# 541   1767150  2400         3          1       no        no       no
# 542   1750000  3620         2          1      yes        no       no
# 543   1750000  2910         3          1       no        no       no
# 544   1750000  3850         3          1      yes        no       no
#
#     hotwaterheating airconditioning  parking furnishingstatus
# 0                no             yes        2        furnished
# ...

# %%
y
# Out:
# 0      2
# 1      3
# 2      1
# 3      1
# 4      1
#       ..
# 540    0
# 541    0
# 542    0
# 543    0
# 544    1
# Name: stories, Length: 545, dtype: int64

# %%
x = data.iloc[:,0:1]

# %%
x
# Out:
#         price
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# ..        ...
# 540   1820000
# 541   1767150
# 542   1750000
# 543   1750000
# 544   1750000
#
# [545 rows x 1 columns]

# %%
y = data.iloc[:,0:1]

# %%
y
# Out:
#         price
# 0    13300000
# 1    12250000
# 2    12250000
# 3    12215000
# 4    11410000
# ..        ...
# 540   1820000
# 541   1767150
# 542   1750000
# 543   1750000
# 544   1750000
#
# [545 rows x 1 columns]

# %%
#9. scale the independent variables

from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# Scale the independent variables
x_scaled = scaler.fit_transform(x)

x_scaled
# Out:
# array([[ 4.56636513e+00],
#        [ 4.00448405e+00],
#        [ 4.00448405e+00],
#        [ 3.98575468e+00],
#        [ 3.55497918e+00],
#        [ 3.25530927e+00],
#        [ 2.88072189e+00],
#        [ 2.88072189e+00],
#        [ 2.73088693e+00],
#        [ 2.69342819e+00],
#        [ 2.69342819e+00],
#        [ 2.62974834e+00],
#        [ 2.43121702e+00],
#        [ 2.39375829e+00],
#        [ 2.39375829e+00],
#        [ 2.31884081e+00],
#        [ 2.31884081e+00],
#        [ 2.24392333e+00],
#        [ 2.20646459e+00],
#        [ 2.18773522e+00],
#        [ 2.13154711e+00],
#        [ 2.09408838e+00],
#        [ 2.07535901e+00],
#        [ 2.07535901e+00],
#        [ 2.03790027e+00],
#        [ 2.01917090e+00],
#        [ 1.97796629e+00],
#        [ 1.94425342e+00],
#        [ 1.94425342e+00],
#        [ 1.94425342e+00],
#        [ 1.94425342e+00],
#        [ 1.94425342e+00],
#        [ 1.88806531e+00],
#        [ 1.83187721e+00],
#        [ 1.79441847e+00],
# ...

# %%
# 10. split the data into training and testing 
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.20,random_state=0)

# %%
print(x_train.shape)
print(x_test.shape)
print(y_train.shape)
print(y_test.shape)
# Out:
# (436, 1)
# (109, 1)
# (436, 1)
# (109, 1)

# %%
# 11. build the model
# Linear regression
from sklearn.linear_model import LinearRegression
lr = LinearRegression()

# %%
# 12. train the model
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# 13. test the model
y_pred = lr.predict(x_test)

# %%
y_pred
# Out:
# array([[ 4585000.],
#        [ 6083000.],
#        [ 4007500.],
#        [ 6930000.],
#        [ 2940000.],
#        [ 6195000.],
#        [ 3535000.],
#        [ 2940000.],
#        [ 3500000.],
#        [ 7980000.],
#        [ 6755000.],
#        [ 3990000.],
#        [ 3150000.],
#        [ 3290000.],
#        [ 4130000.],
#        [ 2660000.],
#        [ 4410000.],
#        [ 3710000.],
#        [ 3360000.],
#        [ 4270000.],
#        [ 5005000.],
#        [ 5383000.],
#        [ 6440000.],
#        [ 1890000.],
#        [ 6125000.],
#        [ 5460000.],
#        [ 5803000.],
#        [ 4620000.],
#        [ 5530000.],
#        [ 5950000.],
#        [ 4305000.],
#        [ 3640000.],
#        [ 5250000.],
#        [ 3325000.],
#        [ 3703000.],
#        [ 4753000.],
#        [ 9100000.],
#        [ 3500000.],
#        [ 3150000.],
#        [ 4270000.],
#        [ 8960000.],
#        [ 4060000.],
#        [ 5740000.],
#        [ 3129000.],
#        [ 3633000.],
# ...

# %%
y_test
# Out:
#        price
# 239  4585000
# 113  6083000
# 325  4007500
# 66   6930000
# 479  2940000
# ..       ...
# 76   6650000
# 132  5810000
# 311  4123000
# 464  3080000
# 155  5530000
#
# [109 rows x 1 columns]

# %%
E = y_test - y_pred
E
# Out:
#             price
# 239  0.000000e+00
# 113  0.000000e+00
# 325  0.000000e+00
# 66  -9.313226e-10
# 479  4.656613e-10
# ..            ...
# 76  -9.313226e-10
# 132  0.000000e+00
# 311  0.000000e+00
# 464  4.656613e-10
# 155  0.000000e+00
#
# [109 rows x 1 columns]

# %%
from sklearn.metrics import r2_score
acc=r2_score(y_pred,y_test)
acc
# Out:
# 1.0

# %%
y_pr=lr.predict([[12]])
y_pr
# Out:
# C:\Users\lenovo\anaconda3\lib\site-packages\sklearn\base.py:420: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[12.]])

# %%
plt.scatter(x_train,y_train)
plt.plot(x_train,lr.predict(x_train),'r')

# %%
plt.scatter(x_test,y_test)
plt.plot(x_test,y_pred,'r')

# %% [raw]
# #14. evaluate the metrics
# from sklearn.metrics import mean_squared_error,r2_score, mean_absolute_error

# %%
error=y_test-y_pred

# %%
error
# Out:
#             price
# 239  0.000000e+00
# 113  0.000000e+00
# 325  0.000000e+00
# 66  -9.313226e-10
# 479  4.656613e-10
# ..            ...
# 76  -9.313226e-10
# 132  0.000000e+00
# 311  0.000000e+00
# 464  4.656613e-10
# 155  0.000000e+00
#
# [109 rows x 1 columns]

# %%
se = error*error

# %%
se
# Out:
#             price
# 239  0.000000e+00
# 113  0.000000e+00
# 325  0.000000e+00
# 66   8.673617e-19
# 479  2.168404e-19
# ..            ...
# 76   8.673617e-19
# 132  0.000000e+00
# 311  0.000000e+00
# 464  2.168404e-19
# 155  0.000000e+00
#
# [109 rows x 1 columns]

# %%
from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score

# Regression metrics
mea = mean_absolute_error(y_test, y_pred)
mse = mean_squared_error(y_test, y_pred)
rmse = np.sqrt(mse)
r2 = r2_score(y_test, y_pred)

# %%
mea
# Out:
# 1.4952426656670527e-10

# %%
mse
# Out:
# 1.1737234527824726e-19

# %%
rmse
# Out:
# 3.4259647586956767e-10

# %%
r2
# Out:
# 1.0
